# %% [markdown]
# # Importing necessary files

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 

#Doing plotting inline
# %matplotlib inline

# %% [markdown]
# # Load and review data

# %%
data_frame = pd.read_csv("D:\Diabetics dataset\pima-data.csv")
data_frame.shape
# Out:
# (768, 10)

# %%
data_frame.head(5)
# Out:
#    num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  diab_pred  \
# 0         6           148            72         35        0  33.6      0.627
# 1         1            85            66         29        0  26.6      0.351
# 2         8           183            64          0        0  23.3      0.672
# 3         1            89            66         23       94  28.1      0.167
# 4         0           137            40         35      168  43.1      2.288
#
#    age    skin diabetes
# 0   50  1.3790     True
# 1   31  1.1426    False
# 2   32  0.0000     True
# 3   21  0.9062    False
# 4   33  1.3790     True

# %%
data_frame.tail(5)
# Out:
#      num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  \
# 763        10           101            76         48      180  32.9
# 764         2           122            70         27        0  36.8
# 765         5           121            72         23      112  26.2
# 766         1           126            60          0        0  30.1
# 767         1            93            70         31        0  30.4
#
#      diab_pred  age    skin diabetes
# 763      0.171   63  1.8912    False
# 764      0.340   27  1.0638    False
# 765      0.245   30  0.9062    False
# 766      0.349   47  0.0000     True
# 767      0.315   23  1.2214    False

# %%
data_frame.isnull()
# Out:
#     num_preg glucose_conc diastolic_bp thickness insulin    bmi diab_pred  \
# 0      False        False        False     False   False  False     False
# 1      False        False        False     False   False  False     False
# 2      False        False        False     False   False  False     False
# 3      False        False        False     False   False  False     False
# 4      False        False        False     False   False  False     False
# 5      False        False        False     False   False  False     False
# 6      False        False        False     False   False  False     False
# 7      False        False        False     False   False  False     False
# 8      False        False        False     False   False  False     False
# 9      False        False        False     False   False  False     False
# 10     False        False        False     False   False  False     False
# 11     False        False        False     False   False  False     False
# ...

# %%
data_frame.isnull().values.any()
# Out:
# False

# %%
def corr_heatmap(data_frame, size = 11):
    
    
    # Getting correlation using pandas
    correlation = data_frame.corr()
    
    #Dividing the plot into subplot for increasing the size
    fig, heatmap = plt.subplots(figsize=(size, size))
    
    #plotting the heatmap correlation heatmap
    heatmap.matshow(correlation)
    
    # Adding xticks & yticks
    plt.xticks(range(len(correlation.columns)), correlation.columns)
    plt.yticks(range(len(correlation.columns)), correlation.columns)
    
    # Displaing the graph
    plt.show()

# %%
corr_heatmap(data_frame, 10)

# %%
data_frame.head()
# Out:
#    num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  diab_pred  \
# 0         6           148            72         35        0  33.6      0.627
# 1         1            85            66         29        0  26.6      0.351
# 2         8           183            64          0        0  23.3      0.672
# 3         1            89            66         23       94  28.1      0.167
# 4         0           137            40         35      168  43.1      2.288
#
#    age    skin diabetes
# 0   50  1.3790     True
# 1   31  1.1426    False
# 2   32  0.0000     True
# 3   21  0.9062    False
# 4   33  1.3790     True

# %% [markdown]
# # Deleting skin column completely

# %%
del data_frame["skin"]
data_frame.head()
# Out:
#    num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  diab_pred  \
# 0         6           148            72         35        0  33.6      0.627
# 1         1            85            66         29        0  26.6      0.351
# 2         8           183            64          0        0  23.3      0.672
# 3         1            89            66         23       94  28.1      0.167
# 4         0           137            40         35      168  43.1      2.288
#
#    age diabetes
# 0   50     True
# 1   31    False
# 2   32     True
# 3   21    False
# 4   33     True

# %%
corr_heatmap(data_frame, 8)

# %% [markdown]
# # See, the skin column is gone !

# %%
data_frame.head()
# Out:
#    num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  diab_pred  \
# 0         6           148            72         35        0  33.6      0.627
# 1         1            85            66         29        0  26.6      0.351
# 2         8           183            64          0        0  23.3      0.672
# 3         1            89            66         23       94  28.1      0.167
# 4         0           137            40         35      168  43.1      2.288
#
#    age diabetes
# 0   50     True
# 1   31    False
# 2   32     True
# 3   21    False
# 4   33     True

# %% [markdown]
# # Making True to 1 and False to 0

# %%
# maping the values
map_diabetes = {True: 1, False: 0}

# setting the map into the data_frames
data_frame["diabetes"] = data_frame["diabetes"].map(map_diabetes)

# showing the data again 
data_frame.head()
# Out:
#    num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  diab_pred  \
# 0         6           148            72         35        0  33.6      0.627
# 1         1            85            66         29        0  26.6      0.351
# 2         8           183            64          0        0  23.3      0.672
# 3         1            89            66         23       94  28.1      0.167
# 4         0           137            40         35      168  43.1      2.288
#
#    age  diabetes
# 0   50         1
# 1   31         0
# 2   32         1
# 3   21         0
# 4   33         1

# %% [markdown]
# # Lets' see how many patient have their diabetes or not

# %% [markdown]
# # or in a pythonic way

# %%
num_true = len(data_frame.loc[data_frame['diabetes'] == True])
num_false = len(data_frame.loc[data_frame['diabetes'] == False])
print "Number of True Cases: {0} ({1:2.2f}%)".format(num_true, ((float)num_true / (num_true + num_false)) * 100)
print "Number of False Cases: {0} ({1:2.2f}%)".format(num_false, ((float)num_true / (num_true + num_false)) * 100)
# Out:
#   File "<ipython-input-19-ce84cbe4ef4a>", line 3
#     print "Number of True Cases: {0} ({1:2.2f}%)".format(num_true, ((float)num_true / (num_true + num_false)) * 100)
#                                                                                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Splitting Data

# %%
from sklearn.cross_validation import train_test_split

feature_column_names = ["num_preg", "glucose_conc", "diastolic_bp", "thickness", "insulin", "bmi", "diab_pred", "age"]
predicted_class_name = ["diabetes"]

# getting feature variable in graph X & y axis
X = data_frame[feature_column_names].values
y = data_frame[predicted_class_name].values

# saving 30% for the test
split_test_size = 30

# splitting using sklearn train_test_split function
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = split_test_size, random_state = 42)

# %% [markdown]
# # let's see if the splitting works or not...

# %%
print("{0:0.2f}% in training set".format((len(X_train)/len(data_frame.index)) * 100))
print("{0:0.2f}% in test set".format(float(len(X_test)/len(data_frame.index)* 100)))

# %%
print("{1} {0}% in test set".format(X_train, (len(X_test)/len(data_frame.index)* 100)))

# %%
t = len(data_frame)
n = 23
p = num_true/t*100
print(t)
print(num_true)
print(p)
print("{0}, {1:2.2f}%".format(num_true, p))

# %%
z = (2/7)*100

print(float(z))

# %%
print(len(data_frame))
# Out:
# 768
